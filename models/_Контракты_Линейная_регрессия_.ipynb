# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('contracts.csv')
df = df.fillna(0)

# %%
df.head(15)
# Out:
#               GroupName ContractDate  ContractPrice
# 0                Прочее   2017-11-15   4.233391e+11
# 1                Прочее   2018-08-06   1.855412e+11
# 2                Прочее   2017-09-18   1.273564e+11
# 3                Прочее   2019-01-10   9.434806e+10
# 4                Прочее   2016-12-12   7.669857e+10
# 5   Строительный надзор   2020-12-28   6.052112e+10
# 6                Прочее   2018-04-03   5.442693e+10
# 7                Прочее   2017-11-13   5.258657e+10
# 8                Прочее   2019-05-27   5.240221e+10
# 9                Прочее   2018-05-25   5.168116e+10
# 10               Прочее   2019-05-15   5.006983e+10
# 11               Прочее   2019-12-23   4.909239e+10
# 12               Прочее   2019-12-27   4.607025e+10
# 13               Прочее   2016-02-11   4.531185e+10
# 14               Прочее   2018-12-24   4.445511e+10

# %%
df['Date'] = pd.to_datetime(df['ContractDate'])
del df['ContractDate']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9645 entries, 0 to 9644
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GroupName      9645 non-null   object
#  1   ContractPrice  9645 non-null   float64
#  2   Date           9645 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 226.2+ KB

# %%
df
# Out:
#                                  GroupName  ContractPrice       Date
# 0                                   Прочее   4.233391e+11 2017-11-15
# 1                                   Прочее   1.855412e+11 2018-08-06
# 2                                   Прочее   1.273564e+11 2017-09-18
# 3                                   Прочее   9.434806e+10 2019-01-10
# 4                                   Прочее   7.669857e+10 2016-12-12
# ...                                    ...            ...        ...
# 9640  Проектно-изыскательские работы (ПИР)   9.055260e+03 2019-02-23
# 9641  Проектно-изыскательские работы (ПИР)   8.291660e+03 2021-06-19
# 9642                                Прочее   2.633000e+03 2019-01-20
# 9643  Проектно-изыскательские работы (ПИР)   1.189890e+03 2020-11-08
# 9644  Проектно-изыскательские работы (ПИР)   1.000000e+03 2020-10-03
#
# [9645 rows x 3 columns]

# %%
df = df.pivot(index='Date', columns='GroupName', values='ContractPrice')

# %%
df = df.reset_index()

# %%
df.fillna(0)
# Out:
# GroupName       Date  Подключение коммуникаций  \
# 0         2016-01-01                       0.0
# 1         2016-01-02                       0.0
# 2         2016-01-03                       0.0
# 3         2016-01-04                       0.0
# 4         2016-01-05                       0.0
# ...              ...                       ...
# 2421      2022-09-12                       0.0
# 2422      2022-09-13                       0.0
# 2423      2022-09-14                       0.0
# 2424      2022-09-15                       0.0
# 2425      2022-09-16                       0.0
#
# GroupName  Проектно-изыскательские работы (ПИР)        Прочее  \
# 0                                   41924136.61  1.327026e+09
# 1                                   16888986.71  7.238227e+08
# 2                                    8064302.51  6.122077e+07
# 3                                     421092.83  5.705191e+08
# 4                                     820983.99  3.271664e+08
# ...

# %%
df
# Out:
# GroupName       Date  Подключение коммуникаций  \
# 0         2016-01-01                       NaN
# 1         2016-01-02                       NaN
# 2         2016-01-03                       NaN
# 3         2016-01-04                       NaN
# 4         2016-01-05                       NaN
# ...              ...                       ...
# 2421      2022-09-12                       NaN
# 2422      2022-09-13                       NaN
# 2423      2022-09-14                       NaN
# 2424      2022-09-15                       NaN
# 2425      2022-09-16                       NaN
#
# GroupName  Проектно-изыскательские работы (ПИР)        Прочее  \
# 0                                   41924136.61  1.327026e+09
# 1                                   16888986.71  7.238227e+08
# 2                                    8064302.51  6.122077e+07
# 3                                     421092.83  5.705191e+08
# 4                                     820983.99  3.271664e+08
# ...

# %%
df.columns.values[0] = "Date"
df.columns.values[1] = "Communication"
df.columns.values[2] = "DesignSurveyWork"
df.columns.values[3] = "Others"
df.columns.values[4] = "ConstructionInstallationWorks"
df.columns.values[5] = "ConstructionSupervision"

# %%
df
# Out:
# GroupName       Date  Communication  DesignSurveyWork        Others  \
# 0         2016-01-01            NaN       41924136.61  1.327026e+09
# 1         2016-01-02            NaN       16888986.71  7.238227e+08
# 2         2016-01-03            NaN        8064302.51  6.122077e+07
# 3         2016-01-04            NaN         421092.83  5.705191e+08
# 4         2016-01-05            NaN         820983.99  3.271664e+08
# ...              ...            ...               ...           ...
# 2421      2022-09-12            NaN       24394638.00  1.681281e+08
# 2422      2022-09-13            NaN       69170000.00  1.873002e+07
# 2423      2022-09-14            NaN               NaN  1.132025e+09
# 2424      2022-09-15            NaN               NaN  3.890009e+07
# 2425      2022-09-16            NaN         373500.00  1.593661e+08
#
# GroupName  ConstructionInstallationWorks  ConstructionSupervision
# 0                           1.036694e+08             1.876290e+08
# ...

# %%
df = df.fillna(0)

# %%
df.head(15)
# Out:
# GroupName       Date  Communication  DesignSurveyWork        Others  \
# 0         2016-01-01           0.00      4.192414e+07  1.327026e+09
# 1         2016-01-02           0.00      1.688899e+07  7.238227e+08
# 2         2016-01-03           0.00      8.064303e+06  6.122077e+07
# 3         2016-01-04           0.00      4.210928e+05  5.705191e+08
# 4         2016-01-05           0.00      8.209840e+05  3.271664e+08
# 5         2016-01-06           0.00      2.037389e+07  8.134865e+07
# 6         2016-01-07           0.00      1.459267e+06  9.664932e+08
# 7         2016-01-08           0.00      8.317040e+05  4.275108e+07
# 8         2016-01-09           0.00      2.219863e+05  1.892794e+09
# 9         2016-01-10           0.00      2.630073e+07  9.952869e+06
# 10        2016-01-11      501169.00      7.034404e+08  1.119393e+10
# 11        2016-01-12      452641.04      2.915509e+08  9.357047e+08
# 12        2016-01-13           0.00      4.904776e+08  2.576896e+09
# ...

# %%
df.describe()
# Out:
# GroupName                           Date  Communication  DesignSurveyWork  \
# count                               2426   2.426000e+03      2.426000e+03
# mean       2019-05-05 15:35:27.947238400   1.180447e+06      3.538475e+08
# min                  2016-01-01 00:00:00   0.000000e+00      0.000000e+00
# 25%                  2017-09-03 06:00:00   0.000000e+00      6.069696e+06
# 50%                  2019-05-03 12:00:00   0.000000e+00      1.625292e+08
# 75%                  2021-01-06 18:00:00   0.000000e+00      4.167255e+08
# max                  2022-09-16 00:00:00   5.636266e+08      1.038888e+10
# std                                  NaN   1.430198e+07      6.700787e+08
#
# GroupName        Others  ConstructionInstallationWorks  \
# count      2.426000e+03                   2.426000e+03
# mean       4.608709e+09                   4.885364e+08
# min        0.000000e+00                   0.000000e+00
# 25%        2.236243e+08                   2.602103e+07
# ...

# %%
df
# Out:
#       index       Date  Communication  DesignSurveyWork        Others  \
# 0         0 2016-01-01            0.0       41924136.61  1.327026e+09
# 1         1 2016-01-02            0.0       16888986.71  7.238227e+08
# 2         2 2016-01-03            0.0        8064302.51  6.122077e+07
# 3         3 2016-01-04            0.0         421092.83  5.705191e+08
# 4         4 2016-01-05            0.0         820983.99  3.271664e+08
# ...     ...        ...            ...               ...           ...
# 2421   2421 2022-09-12            0.0       24394638.00  1.681281e+08
# 2422   2422 2022-09-13            0.0       69170000.00  1.873002e+07
# 2423   2423 2022-09-14            0.0              0.00  1.132025e+09
# 2424   2424 2022-09-15            0.0              0.00  3.890009e+07
# 2425   2425 2022-09-16            0.0         373500.00  1.593661e+08
#
#       ConstructionInstallationWorks  ConstructionSupervision
# 0                      1.036694e+08             1.876290e+08
# ...

# %%
df = pd.DataFrame(df.to_records())

# %%
df.isnull().sum()
# Out:
# index                            0
# Date                             0
# Communication                    0
# DesignSurveyWork                 0
# Others                           0
# ConstructionInstallationWorks    0
# ConstructionSupervision          0
# dtype: int64

# %%
fig, axs = plt.subplots(5, figsize=(10, 10))
plt1 = sns.boxplot(df['Communication'], ax = axs[0])
plt1 = sns.boxplot(df['DesignSurveyWork'], ax = axs[1])
plt1 = sns.boxplot(df['Others'], ax = axs[2])
plt1 = sns.boxplot(df['ConstructionInstallationWorks'], ax = axs[3])
plt1 = sns.boxplot(df['ConstructionSupervision'], ax = axs[4])

# %%
sns.pairplot(df, x_vars=['Communication', 'DesignSurveyWork', 'ConstructionInstallationWorks', 'ConstructionSupervision', 'Others'], y_vars='Date')

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

X = df['DesignSurveyWork']
y = df['ConstructionInstallationWorks']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
X_train.shape
# Out:
# (1940,)

# %%
X_test.shape
# Out:
# (486,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
# y = ax + b
a = model.coef_
b = model.intercept_
print('y = ' + str(a[0]) + 'x' + '+' + str(b))
# Out:
# y = 0.39792241280613533x+350823683.14599705

# %%
y_pred = model.predict(X_train.values.reshape(-1, 1))

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, y_pred, 'r')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mean_squared_error(y_pred=y_pred, y_true=y_train)
# Out:
# 4.3323772927131046e+17

# %%
mean_absolute_error(y_pred=y_pred, y_true=y_train)
# Out:
# 403576365.47174174

# %%
y_train.mean()
# Out:
# 492108606.3511391

# %%
y_pred = model.predict(X_test.values.reshape(-1, 1))

# %%
plt.scatter(X_test, y_test)
y_error = y_test - y_pred
plt.plot(X_test, y_pred, 'r')
plt.vlines(X_test, y_pred, y_pred + y_error, 'g')

# %%
mean_squared_error(y_pred=y_pred, y_true=y_test)
# Out:
# 7.080681322855876e+17

# %%
mean_absolute_error(y_pred=y_pred, y_true=y_test)
# Out:
# 408528306.561129

# %%
y_test.mean()
# Out:
# 474277034.872572
